# %%
#1.Write a Python program to find words which are greater than given length k?

# %%
def String(Str,k):
    word=[]
    text=Str.split(" ")
    for i in text:
        if len(i)>k:
            word.append(i)
    return word
Str=input("enter the sentence :")
K=int(input("enter the length of word : "))
print("word greater than {} is ".format(k))
print(String(Str,k))
# Out:
# enter the sentence :my name is skb
# enter the length of word : 3
# word greater than 3 is
# ['name']

# %%
#2.Write a Python program for removing i-th character from a string?

# %%
def  remove(Str,x):
    for i in range(len(Str)):
        if x == i:
            Str=Str.replace(Str[i],"",1)
    return Str
    
Str=input("Enter the string :")
x=int(input("Enter the position :"))
print("new string is ",remove(Str,x))
# Out:
# Enter the string :sandeep
# Enter the position :3
# new string is  saneep

# %%
#3.Write a Python program to split and join a string?

# %%
str = input("Enter the string : ")
str = str.split(" ") 
print("Spliting a string : ",str)


str2 = "-".join(str)
print("Joining a string : ",str2)
# Out:
# Enter the string : My name is skb
# Spliting a string :  ['My', 'name', 'is', 'skb']
# Joining a string :  My-name-is-skb

# %%
#4.Write a Python to check if a given string is binary string or not?

# %%
def ifbinary(str):
    binary = '01'
    for i in range(len(str)):
        if str[i] not in binary:
            print('Not Binary')
            break
    else:
        print('Binary')
        
str = input("Enter the string : ")
ifbinary(str)
# Out:
# Enter the string : 10101011
# Binary

# %%
#5.Write a Python program to find uncommon words from two Strings?

# %%
def unCommon(a,b):
    list_one = a.split()
    list_two = b.split()
    notcom =''
    
    for i in list_one:
        if i not in list_two:
            notcom = notcom +" "+ i
    for j in list_two:
        if j not in list_one:
            notcom = notcom +" "+ j
    return notcom

a = input("Enter the string a : ").lower()
b = input("Enter the string b : ").lower()

print("The list of un Common words : ", unCommon(a,b))
# Out:
# Enter the string a : my name skb
# Enter the string b : my name sandeep
# The list of un Common words :   skb sandeep

# %%
#6.Write a Python to find all duplicate characters in string?

# %%
Str = input("Enter the string a : ").lower()
duplicate = []

for i in Str:
    if Str.count(i) > 1 :
        if i not in duplicate:
            duplicate.append(i)
        
duplicate
# Out:
# Enter the string a : my name is sandeep
# ['m', ' ', 'n', 'a', 'e', 's']

# %%
#7.Write a Python Program to check if a string contains any special character?

# %%
import string

str_char = string.punctuation
spec_str = []

str = input("Enter the string : ").lower()
for i in str:
    if i in str_char:
        spec_str.append(i)

print("String \"{} \"has special charecter : {}".format(str,speci_str))
# Out:
# Enter the string a : my n@me i$ &kb
# String "my n@me i$ &kb "has special charecter : ['@', '$', '&']
